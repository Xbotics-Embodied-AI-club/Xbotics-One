# %%
# 从 Hub 加载（自动缓存到本地）
from lerobot.datasets.lerobot_dataset import LeRobotDataset
dataset = LeRobotDataset("lerobot/libero")

# %%
# 查看元信息
print(dataset.meta.total_episodes)   # 1693
print(dataset.meta.total_frames)     # 273465
print(dataset.meta.fps)              # 10.0
print(dataset.meta.camera_keys)      # ['observation.images.image', ...]

# %%
sample = dataset[0]

# %%
sample
